# %%
from langchain.document_loaders import DirectoryLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA
from langchain.chains.question_answering import load_qa_chain
from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma

# %%
#from configparser import ConfigParser
#config_object = ConfigParser()
#config_object.read("config.ini")

##Get the password
#openai_config = config_object["openai"]
#open_ai_key = openai_config['key']

# %%
loader = DirectoryLoader(r"D:\My Files\Areete solutions\LLM_model_rag\data1")
documents = loader.load()

# %%
documents
# Out:
# [Document(page_content='Handbook of\n\nGood Dairy Husbandry Practices\n\nBREEDS OF INDIGENOUS DAIRY CATTLE\n\nBULLS\n\nGir\n\nNative tract: Junagadh, Rajkot,\n\nBhavnagar and Amreli districts\n\nin Gujarat\n\nCOWS\n\nHariana\n\nNative tract: Rohtak, Hissar,\n\nSonepat, Gurgaon, Jind and\n\nJhajjar districts in Haryana\n\nSahiwal\n\nNative tract: Ferozpur and\n\nAmritsar district of Punjab & Shri\n\nGanganagar district of Rajasthan\n\nRathi\n\nNative tract: Bikaner &\n\nShri Ganganagar districts of\n\nRajasthan\n\nRed Sindhi\n\nNative tract: In Pakistan, also\n\nfound in Punjab, Haryana &\n\nRajasthan & Uttarakhand\n\nTharparkar\n\nNative tract: Jaisalmer, Barmer\n\nand Jodhpur districts in\n\nRajasthan\n\nKankrej\n\nNative tract: Kutch, Mehsana &\n\nBanaskantha districts of Gujarat\n\nFOREWORD\n\nCOWS\n\nMurrah\n\nNative tract: Hissar, Rohtak,\n\nGurgaon and Jind districts of\n\nHaryana\n\nWith an annual production of 18.77 crore metric tonnes during 2018-19, India continues to be\n\nranked number one in the world in milk production since 1997. Dairying is the main source\n\nof livelihood for our milk producers, majority of them either landless or marginal farmers. For\n\nmaking dairying a profitable and, sustainable venture, it is important for the dairy farmer to\n\nadopt scientific practices that would lead to increased productivity at optimum costs. For this\n\nto happen, the farmer should be aware of the basic tenets of animal health, breeding and\n\nfeeding.\n\nJaffarabadi\n\nNative tract: Junagadh,\n\nJamnagar, Rajkot, Bhavnagar,\n\nPorbandar & Amreli districts\n\nof Gujarat\n\nThe National Dairy Plan-I (NDP-I) has been launched by the GoI with the aim to double\n\nmilk production in the country by 2020. This would require focused efforts in the field of\n\nbreeding, feeding and animal health, which would increase productivity and optimize costs.\n\nIn breeding, coverage of artificial insemination (AI) needs to be increased using disease free\n\nsemen from high genetic merit bulls. There is also an urgent need to optimize the utilization\n\nof feed resources in order to reduce the cost of milk production through balancing the ration\n\nof animals. More importantly, preventive measures to control occurrence of diseases need to\n\nbe put in place, which is pivotal in harnessing the full production potential of the animal.\n\nNili Ravi\n\nNative tract: Originally from\n\nPakistan, found in bordering\n\ndistricts of Ferozpur and\n\nAmritsar in Punjab\n\nThis handbook on scientific dairy practices has been designed keeping these requirements of\n\nthe dairy farmers in mind. The handbook attempts to provide basic information on breeding,\n\nhealthcare, management, nutrition, fodder production etc, based on existing and new\n\ntechnologies, along with illustrations. Such information is usually not available from a single\n\nsource to the dairy farmer.\n\nPandharpuri\n\nNative tract: Solapur, Sangli\n\nand Kolhapur  districts of\n\nMaharashtra\n\nWe sincerely hope that the handbook would be useful to the dairy farmer.\n\nPART I\n\nANIMAL HEALTH AND BREEDING\n\nAnimal health plays an important role in harnessing the expected production potential\n\nof dairy animals. A diseased animal cannot perform to the expected level. Timely\n\nintervention is therefore pivotal in reducing the economic losses due to diseases.\n\nImprovement of breeds is also the need of the hour and the farmer needs to be made\n\naware of various aspects of breeding to be an active participant of breed improvement\n\nprogrammes. With this aim, the Part I of  this booklet is divided into XIV sections which\n\nare as under:\n\nSection I\n\nSection II\n\nSection III\n\nSection IV\n\nSection V\n\nSection VI\n\nSection VII\n\nGeneral observation of an animal\n\nBuying and inducting a new animal\n\nCare of new born calf\n\nDiseases preventable by vaccination\n\nOther important diseases\n\nTick and fly borne diseases\n\nTick, Fly and worm control\n\nSection VIII Dis ...

# %%
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=50)
texts = text_splitter.split_documents(documents)

# %%
len(texts)
# Out:
# 144

# %%
#embeddings = OpenAIEmbeddings(openai_api_key=open_ai_key)
#docsearch = Chroma.from_documents(texts, embeddings)
# Out:
# d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[38], line 2
#       1 embeddings = OpenAIEmbeddings(openai_api_key=open_ai_key)
# ----> 2 docsearch = Chroma.from_documents(texts, embeddings)
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\langchain_community\vectorstores\chroma.py:790, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     788 texts = [doc.page_content for doc in documents]
#     789 metadatas = [doc.metadata for doc in documents]
# --> 790 return cls.from_texts(
#     791     texts=texts,
#     792     embedding=embedding,
#     793     metadatas=metadatas,
#     794     ids=ids,
#     795     collection_name=collection_name,
#     796     persist_directory=persist_directory,
#     797     client_settings=client_settings,
#     798     client=client,
#     799     collection_metadata=collection_metadata,
#     800     **kwargs,
#     801 )
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\langchain_community\vectorstores\chroma.py:748, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     740     from chromadb.utils.batch_utils import create_batches
#     742     for batch in create_batches(
#     743         api=chroma_collection._client,
#     744         ids=ids,
#     745         metadatas=metadatas,
#     746         documents=texts,
#     747     ):
# --> 748         chroma_collection.add_texts(
#     749             texts=batch[3] if batch[3] else [],
#     750             metadatas=batch[2] if batch[2] else None,
#     751             ids=batch[0],
#     752         )
#     753 else:
#     754     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\langchain_community\vectorstores\chroma.py:276, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     274 texts = list(texts)
#     275 if self._embedding_function is not None:
# --> 276     embeddings = self._embedding_function.embed_documents(texts)
#     277 if metadatas:
#     278     # fill metadatas with empty dicts if somebody
#     279     # did not specify metadata for all texts
#     280     length_diff = len(texts) - len(metadatas)
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\langchain_community\embeddings\openai.py:668, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     665 # NOTE: to keep things simple, we assume the list may contain texts longer
#     666 #       than the maximum context and use length-safe embedding function.
#     667 engine = cast(str, self.deployment)
# --> 668 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\langchain_community\embeddings\openai.py:494, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     492 batched_embeddings: List[List[float]] = []
#     493 for i in _iter:
# --> 494     response = embed_with_retry(
#     495         self,
#     496         input=tokens[i : i + _chunk_size],
#     497         **self._invocation_params,
#     498     )
#     499     if not isinstance(response, dict):
#     500         response = response.dict()
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\langchain_community\embeddings\openai.py:116, in embed_with_retry(embeddings, **kwargs)
#     114 """Use tenacity to retry the embedding call."""
#     115 if is_openai_v1():
# --> 116     return embeddings.client.create(**kwargs)
#     117 retry_decorator = _create_retry_decorator(embeddings)
#     119 @retry_decorator
#     120 def _embed_with_retry(**kwargs: Any) -> Any:
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\openai\resources\embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     108         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     109             base64.b64decode(data), dtype="float32"
#     110         ).tolist()
#     112     return obj
# --> 114 return self._post(
#     115     "/embeddings",
#     116     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     117     options=make_request_options(
#     118         extra_headers=extra_headers,
#     119         extra_query=extra_query,
#     120         extra_body=extra_body,
#     121         timeout=timeout,
#     122         post_parser=parser,
#     123     ),
#     124     cast_to=CreateEmbeddingResponse,
#     125 )
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\openai\_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\openai\_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\openai\_base_client.py:1005, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1003 if retries > 0 and self._should_retry(err.response):
#    1004     err.response.close()
# -> 1005     return self._retry_request(
#    1006         options,
#    1007         cast_to,
#    1008         retries,
#    1009         err.response.headers,
#    1010         stream=stream,
#    1011         stream_cls=stream_cls,
#    1012     )
#    1014 # If the response is streamed then we need to explicitly read the response
#    1015 # to completion before attempting to access the response text.
#    1016 if not err.response.is_closed:
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\openai\_base_client.py:1053, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1049 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1050 # different thread if necessary.
#    1051 time.sleep(timeout)
# -> 1053 return self._request(
#    1054     options=options,
#    1055     cast_to=cast_to,
#    1056     remaining_retries=remaining,
#    1057     stream=stream,
#    1058     stream_cls=stream_cls,
#    1059 )
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\openai\_base_client.py:1005, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1003 if retries > 0 and self._should_retry(err.response):
#    1004     err.response.close()
# -> 1005     return self._retry_request(
#    1006         options,
#    1007         cast_to,
#    1008         retries,
#    1009         err.response.headers,
#    1010         stream=stream,
#    1011         stream_cls=stream_cls,
#    1012     )
#    1014 # If the response is streamed then we need to explicitly read the response
#    1015 # to completion before attempting to access the response text.
#    1016 if not err.response.is_closed:
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\openai\_base_client.py:1053, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1049 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1050 # different thread if necessary.
#    1051 time.sleep(timeout)
# -> 1053 return self._request(
#    1054     options=options,
#    1055     cast_to=cast_to,
#    1056     remaining_retries=remaining,
#    1057     stream=stream,
#    1058     stream_cls=stream_cls,
#    1059 )
#
# File d:\My Files\Areete solutions\LLM_model_rag\llmenv\Lib\site-packages\openai\_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1027     stream_cls=stream_cls,
#    1028 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
docsearch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 docsearch
#
# NameError: name 'docsearch' is not defined

# %%
model_name= "gpt-3.5-turbo"
#llm = ChatOpenAI(openai_api_key=open_ai_key,
                    model_name=model_name, temperature=0)
retriever=docsearch.as_retriever()
qa_chain = RetrievalQA.from_chain_type(llm, chain_type="stuff", retriever=retriever, verbose=True)

# %%
query = "What is ration balancing?"
response = qa_chain.run(query)

# %%
response

# %%
qa_chain2 = load_qa_chain(llm, chain_type="stuff",verbose=True)

# %%
matching_documents = docsearch.similarity_search(query)
matching_documents

# %%
response = qa_chain2.run(input_documents = matching_documents,question=query)

# %%
response
